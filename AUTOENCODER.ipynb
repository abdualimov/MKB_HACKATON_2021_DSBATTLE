# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
from matplotlib.pyplot import figure
import seaborn as sns

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve, accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.preprocessing import RobustScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import MinMaxScaler
import scikitplot as skplt
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.metrics import Accuracy, Precision, Recall, AUC, TrueNegatives, TruePositives, FalseNegatives, FalsePositives
from tensorflow.keras.optimizers import Adam, Adamax, Nadam
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

from sklearn.linear_model import LogisticRegression
import lightgbm as lgb

# %%
data = pd.read_csv('data_prepared_to_AI_101')
test = pd.read_csv('test_dataset_hackathon_mkb.csv', sep=';', encoding='cp1251')

train_data = data.query('sample == 1').drop(['sample'], axis=1)
test_data = data.query('sample == 0').drop(['sample'], axis=1)
test_data = test_data.drop(['TARGET'], axis=1)

y = train_data['TARGET']            # наш таргет
X = train_data.drop(['TARGET'], axis=1)

# %%
X_train, X_test, y_train, y_test = X.iloc[:14000,], X.iloc[14000:,], y[:14000,], y[14000:,]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
data_train = scaler.transform(X_train)
data_test = scaler.transform(X_test)

# %%
tf.keras.backend.clear_session()
encoding_dim = 30

#Encoder
input_ = Input(shape=(2167, ))
x = Dense(encoding_dim*3, activation='elu')(input_)
x = Dense(encoding_dim*2, activation='elu')(x)
encoded = Dense(encoding_dim, activation="sigmoid")(x)

#Decoder
input_encoded = Input(shape=(encoding_dim,))
x = Dense(encoding_dim*2, activation='elu')(input_encoded)
x = Dense(encoding_dim*3, activation='elu')(x)
flat_decoded = Dense(2167, activation='sigmoid')(x)
decoded = Reshape((2167, 1))(flat_decoded)

encoder = Model(input_, encoded, name="encoder")
decoder = Model(input_encoded, decoded, name="decoder")
autoencoder = Model(input_, decoder(encoder(input_)), name="autoencoder")

autoencoder.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2167)]            0
#
#  encoder (Functional)        (None, 30)                202410
#
#  decoder (Functional)        (None, 2167, 1)           204547
#
# =================================================================
# Total params: 406,957
# Trainable params: 406,957
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint('best_model_after_autoencoder.hdf5' , 
                             monitor = 'loss', 
                             verbose = 1, 
                             save_best_only=True,
                             mode = 'min',
                             save_weights_only=True,
                             save_freq='epoch'
                            )
callbacks_list = [checkpoint]

autoencoder.fit(data_train, data_train,
                epochs=100,
                shuffle=True,
                callbacks=callbacks_list,
                )
# Out:
# Epoch 1/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9286
# Epoch 00001: loss improved from inf to 0.03486, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0349 - accuracy: 0.9286
# Epoch 2/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9420
# Epoch 00002: loss improved from 0.03486 to 0.02184, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0218 - accuracy: 0.9420
# Epoch 3/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9487
# Epoch 00003: loss improved from 0.02184 to 0.01661, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 5ms/step - loss: 0.0166 - accuracy: 0.9488
# Epoch 4/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9500
# Epoch 00004: loss improved from 0.01661 to 0.01554, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0155 - accuracy: 0.9500
# Epoch 5/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9510
# Epoch 00005: loss improved from 0.01554 to 0.01486, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0149 - accuracy: 0.9510
# Epoch 6/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9518
# Epoch 00006: loss improved from 0.01486 to 0.01420, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0142 - accuracy: 0.9518
# Epoch 7/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9528
# Epoch 00007: loss improved from 0.01420 to 0.01344, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0134 - accuracy: 0.9528
# Epoch 8/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9541
# Epoch 00008: loss improved from 0.01344 to 0.01248, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0125 - accuracy: 0.9541
# Epoch 9/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9549
# Epoch 00009: loss improved from 0.01248 to 0.01179, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0118 - accuracy: 0.9549
# Epoch 10/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9556
# Epoch 00010: loss improved from 0.01179 to 0.01127, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0113 - accuracy: 0.9556
# Epoch 11/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9561
# Epoch 00011: loss improved from 0.01127 to 0.01084, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0108 - accuracy: 0.9561
# Epoch 12/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9564
# Epoch 00012: loss improved from 0.01084 to 0.01055, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0105 - accuracy: 0.9564
# Epoch 13/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9567
# Epoch 00013: loss improved from 0.01055 to 0.01027, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0103 - accuracy: 0.9567
# Epoch 14/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9570
# Epoch 00014: loss improved from 0.01027 to 0.01001, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0100 - accuracy: 0.9570
# Epoch 15/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9574
# Epoch 00015: loss improved from 0.01001 to 0.00976, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0098 - accuracy: 0.9573
# Epoch 16/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9576
# Epoch 00016: loss improved from 0.00976 to 0.00954, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0095 - accuracy: 0.9576
# Epoch 17/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9578
# Epoch 00017: loss improved from 0.00954 to 0.00936, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0094 - accuracy: 0.9578
# Epoch 18/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9580
# Epoch 00018: loss improved from 0.00936 to 0.00920, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0092 - accuracy: 0.9580
# Epoch 19/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9582
# Epoch 00019: loss improved from 0.00920 to 0.00903, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0090 - accuracy: 0.9582
# Epoch 20/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9584
# Epoch 00020: loss improved from 0.00903 to 0.00886, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0089 - accuracy: 0.9584
# Epoch 21/100
# 434/438 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9585
# Epoch 00021: loss improved from 0.00886 to 0.00872, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0087 - accuracy: 0.9586
# Epoch 22/100
# 431/438 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9588
# Epoch 00022: loss improved from 0.00872 to 0.00856, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0086 - accuracy: 0.9587
# Epoch 23/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9589
# Epoch 00023: loss improved from 0.00856 to 0.00842, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0084 - accuracy: 0.9589
# Epoch 24/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9591
# Epoch 00024: loss improved from 0.00842 to 0.00828, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0083 - accuracy: 0.9591
# Epoch 25/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9592
# Epoch 00025: loss improved from 0.00828 to 0.00816, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0082 - accuracy: 0.9592
# Epoch 26/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9593
# Epoch 00026: loss improved from 0.00816 to 0.00806, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0081 - accuracy: 0.9593
# Epoch 27/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9595
# Epoch 00027: loss improved from 0.00806 to 0.00795, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0080 - accuracy: 0.9595
# Epoch 28/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9596
# Epoch 00028: loss improved from 0.00795 to 0.00786, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0079 - accuracy: 0.9596
# Epoch 29/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9597
# Epoch 00029: loss improved from 0.00786 to 0.00775, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0078 - accuracy: 0.9597
# Epoch 30/100
# 431/438 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9598
# Epoch 00030: loss improved from 0.00775 to 0.00767, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0077 - accuracy: 0.9598
# Epoch 31/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9599
# Epoch 00031: loss improved from 0.00767 to 0.00759, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0076 - accuracy: 0.9599
# Epoch 32/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9600
# Epoch 00032: loss improved from 0.00759 to 0.00751, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0075 - accuracy: 0.9600
# Epoch 33/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9601
# Epoch 00033: loss improved from 0.00751 to 0.00742, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0074 - accuracy: 0.9601
# Epoch 34/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9602
# Epoch 00034: loss improved from 0.00742 to 0.00737, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0074 - accuracy: 0.9602
# Epoch 35/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9603
# Epoch 00035: loss improved from 0.00737 to 0.00731, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 5ms/step - loss: 0.0073 - accuracy: 0.9603
# Epoch 36/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9603
# Epoch 00036: loss improved from 0.00731 to 0.00726, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0073 - accuracy: 0.9603
# Epoch 37/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9604
# Epoch 00037: loss improved from 0.00726 to 0.00719, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0072 - accuracy: 0.9604
# Epoch 38/100
# 431/438 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9605
# Epoch 00038: loss improved from 0.00719 to 0.00714, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0071 - accuracy: 0.9605
# Epoch 39/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9605
# Epoch 00039: loss improved from 0.00714 to 0.00710, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0071 - accuracy: 0.9605
# Epoch 40/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9606
# Epoch 00040: loss improved from 0.00710 to 0.00703, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0070 - accuracy: 0.9606
# Epoch 41/100
# 434/438 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9606
# Epoch 00041: loss improved from 0.00703 to 0.00700, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0070 - accuracy: 0.9606
# Epoch 42/100
# 434/438 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9607
# Epoch 00042: loss improved from 0.00700 to 0.00693, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0069 - accuracy: 0.9607
# Epoch 43/100
# 431/438 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9608
# Epoch 00043: loss improved from 0.00693 to 0.00689, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0069 - accuracy: 0.9608
# Epoch 44/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9608
# Epoch 00044: loss improved from 0.00689 to 0.00684, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0068 - accuracy: 0.9608
# Epoch 45/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9609
# Epoch 00045: loss improved from 0.00684 to 0.00681, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0068 - accuracy: 0.9609
# Epoch 46/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9610
# Epoch 00046: loss improved from 0.00681 to 0.00673, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0067 - accuracy: 0.9610
# Epoch 47/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9610
# Epoch 00047: loss improved from 0.00673 to 0.00669, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0067 - accuracy: 0.9610
# Epoch 48/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9610
# Epoch 00048: loss improved from 0.00669 to 0.00668, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0067 - accuracy: 0.9610
# Epoch 49/100
# 428/438 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9611
# Epoch 00049: loss improved from 0.00668 to 0.00662, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0066 - accuracy: 0.9611
# Epoch 50/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9611
# Epoch 00050: loss improved from 0.00662 to 0.00659, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0066 - accuracy: 0.9611
# Epoch 51/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9612
# Epoch 00051: loss improved from 0.00659 to 0.00654, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0065 - accuracy: 0.9612
# Epoch 52/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9612
# Epoch 00052: loss improved from 0.00654 to 0.00651, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0065 - accuracy: 0.9612
# Epoch 53/100
# 428/438 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9613
# Epoch 00053: loss improved from 0.00651 to 0.00647, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0065 - accuracy: 0.9613
# Epoch 54/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9613
# Epoch 00054: loss improved from 0.00647 to 0.00644, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0064 - accuracy: 0.9613
# Epoch 55/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9613
# Epoch 00055: loss improved from 0.00644 to 0.00642, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0064 - accuracy: 0.9613
# Epoch 56/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9614
# Epoch 00056: loss improved from 0.00642 to 0.00637, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0064 - accuracy: 0.9614
# Epoch 57/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9615
# Epoch 00057: loss improved from 0.00637 to 0.00633, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9614
# Epoch 58/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9615
# Epoch 00058: loss improved from 0.00633 to 0.00629, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9615
# Epoch 59/100
# 434/438 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9615
# Epoch 00059: loss improved from 0.00629 to 0.00627, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9615
# Epoch 60/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9616
# Epoch 00060: loss improved from 0.00627 to 0.00624, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0062 - accuracy: 0.9616
# Epoch 61/100
# 425/438 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9616
# Epoch 00061: loss improved from 0.00624 to 0.00620, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0062 - accuracy: 0.9616
# Epoch 62/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9616
# Epoch 00062: loss improved from 0.00620 to 0.00619, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0062 - accuracy: 0.9616
# Epoch 63/100
# 425/438 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9617
# Epoch 00063: loss improved from 0.00619 to 0.00614, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0061 - accuracy: 0.9617
# Epoch 64/100
# 425/438 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9617
# Epoch 00064: loss improved from 0.00614 to 0.00613, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0061 - accuracy: 0.9617
# Epoch 65/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9617
# Epoch 00065: loss improved from 0.00613 to 0.00611, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0061 - accuracy: 0.9617
# Epoch 66/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9618
# Epoch 00066: loss improved from 0.00611 to 0.00608, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0061 - accuracy: 0.9618
# Epoch 67/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9618
# Epoch 00067: loss improved from 0.00608 to 0.00605, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9618
# Epoch 68/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9618
# Epoch 00068: loss improved from 0.00605 to 0.00600, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9618
# Epoch 69/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9619
# Epoch 00069: loss improved from 0.00600 to 0.00598, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9619
# Epoch 70/100
# 431/438 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9619
# Epoch 00070: loss improved from 0.00598 to 0.00596, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9619
# Epoch 71/100
# 424/438 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9619
# Epoch 00071: loss improved from 0.00596 to 0.00594, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9619
# Epoch 72/100
# 435/438 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9619
# Epoch 00072: loss improved from 0.00594 to 0.00592, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9619
# Epoch 73/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9620
# Epoch 00073: loss improved from 0.00592 to 0.00589, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9620
# Epoch 74/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9620
# Epoch 00074: loss improved from 0.00589 to 0.00588, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9620
# Epoch 75/100
# 428/438 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9620
# Epoch 00075: loss improved from 0.00588 to 0.00586, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9620
# Epoch 76/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9621
# Epoch 00076: loss improved from 0.00586 to 0.00582, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9621
# Epoch 77/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9621
# Epoch 00077: loss improved from 0.00582 to 0.00579, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9621
# Epoch 78/100
# 425/438 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9621
# Epoch 00078: loss improved from 0.00579 to 0.00578, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9621
# Epoch 79/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9621
# Epoch 00079: loss improved from 0.00578 to 0.00575, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9621
# Epoch 80/100
# 434/438 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9622
# Epoch 00080: loss improved from 0.00575 to 0.00572, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0057 - accuracy: 0.9622
# Epoch 81/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9622
# Epoch 00081: loss improved from 0.00572 to 0.00570, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0057 - accuracy: 0.9622
# Epoch 82/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9622
# Epoch 00082: loss improved from 0.00570 to 0.00568, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0057 - accuracy: 0.9622
# Epoch 83/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9622
# Epoch 00083: loss improved from 0.00568 to 0.00568, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0057 - accuracy: 0.9622
# Epoch 84/100
# 436/438 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9623
# Epoch 00084: loss improved from 0.00568 to 0.00564, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9623
# Epoch 85/100
# 433/438 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9623
# Epoch 00085: loss improved from 0.00564 to 0.00562, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9623
# Epoch 86/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9623
# Epoch 00086: loss did not improve from 0.00562
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9623
# Epoch 87/100
# 430/438 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9623
# Epoch 00087: loss improved from 0.00562 to 0.00559, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9623
# Epoch 88/100
# 425/438 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9624
# Epoch 00088: loss improved from 0.00559 to 0.00556, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9624
# Epoch 89/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9624
# Epoch 00089: loss improved from 0.00556 to 0.00553, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9624
# Epoch 90/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9624
# Epoch 00090: loss did not improve from 0.00553
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9624
# Epoch 91/100
# 428/438 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9624
# Epoch 00091: loss improved from 0.00553 to 0.00551, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9624
# Epoch 92/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9624
# Epoch 00092: loss did not improve from 0.00551
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9624
# Epoch 93/100
# 437/438 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9625
# Epoch 00093: loss improved from 0.00551 to 0.00545, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9625
# Epoch 94/100
# 428/438 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9625
# Epoch 00094: loss did not improve from 0.00545
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0055 - accuracy: 0.9625
# Epoch 95/100
# 438/438 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9625
# Epoch 00095: loss improved from 0.00545 to 0.00545, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9625
# Epoch 96/100
# 429/438 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9626
# Epoch 00096: loss improved from 0.00545 to 0.00541, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9626
# Epoch 97/100
# 432/438 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9625
# Epoch 00097: loss did not improve from 0.00541
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9625
# Epoch 98/100
# 426/438 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9626
# Epoch 00098: loss did not improve from 0.00541
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9626
# Epoch 99/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9626
# Epoch 00099: loss improved from 0.00541 to 0.00539, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9626
# Epoch 100/100
# 427/438 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9627
# Epoch 00100: loss improved from 0.00539 to 0.00534, saving model to best_model_after_autoencoder.hdf5
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0053 - accuracy: 0.9627

# %%
autoencoder.load_weights('best_model_after_autoencoder.hdf5')
predict_autoencoder_X = autoencoder.predict(data_train)
predict_autoencoder_test_data = autoencoder.predict(data_test)

# %%
data_predict_autoencoder_X = pd.DataFrame(predict_autoencoder_X.reshape(predict_autoencoder_X.shape[0], predict_autoencoder_X.shape[1]))
data_predict_autoencoder_test_data = pd.DataFrame(predict_autoencoder_test_data.reshape(predict_autoencoder_test_data.shape[0], predict_autoencoder_test_data.shape[1]))

# %%
# X_train, X_test, y_train, y_test = data_predict_autoencoder_X.iloc[:14000,], data_predict_autoencoder_X.iloc[14000:,], y[:14000,], y[14000:,]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13, shuffle = False)
scale_pos_weight = sum(y_train == 0) / (1.0 * sum(y_train == 1))

RF_T = CatBoostClassifier(
      verbose=0
    #loss_function='Logloss'
)
RF_T.fit(data_predict_autoencoder_X, y_train)

test_pred = RF_T.predict_proba(data_predict_autoencoder_test_data)[:,1]
test_pred_bin = RF_T.predict(data_predict_autoencoder_test_data)

fpr, tpr, _ = roc_curve(y_test, test_pred)
auc = roc_auc_score(y_test, test_pred)
accuracy = accuracy_score(y_test, test_pred_bin)
f1 = f1_score(y_test, test_pred_bin)
precision =  precision_score(y_test, test_pred_bin)
recall = recall_score(y_test, test_pred_bin)

print('FP, TP              :', "%0.2f" % sum(fpr), "%0.2f" % sum(tpr))
print('ROC_AUC_SCORE       :', "%0.2f" % auc)
print('accuracy            :', "%0.2f" % accuracy)
print('precision           :', "%0.2f" % precision)
print('recall              :', "%0.2f" % recall)
print('f1                  :', "%0.2f" % f1)

print('val, train  AUC     :', "%0.2f" % roc_auc_score(y_test, test_pred), "%0.2f" % roc_auc_score(y_train, RF_T.predict_proba(data_predict_autoencoder_X)[:,1]))
print('val, train  AUC_2   :', "%0.2f" % roc_auc_score(y_test, test_pred_bin), "%0.2f" % roc_auc_score(y_train, RF_T.predict(data_predict_autoencoder_X)))

print(confusion_matrix(y_test, test_pred_bin))
print(classification_report(y_test, RF_T.predict(data_predict_autoencoder_test_data)))
# Out:
# FP, TP              : 194.31 700.85
# ROC_AUC_SCORE       : 0.91
# accuracy            : 0.81
# precision           : 0.91
# recall              : 0.51
# f1                  : 0.66
# val, train  AUC     : 0.91 0.99
# val, train  AUC_2   : 0.74 0.96
# [[2430   67]
#  [ 681  713]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.87      2497
#            1       0.91      0.51      0.66      1394
#
#     accuracy                           0.81      3891
#    macro avg       0.85      0.74      0.76      3891
# weighted avg       0.83      0.81      0.79      3891

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13, shuffle = False)
scale_pos_weight = sum(y_train == 0) / (1.0 * sum(y_train == 1))

RF_T = RandomForestClassifier( n_jobs=-1, random_state=0)
RF_T.fit(data_predict_autoencoder_X, y_train)

test_pred = RF_T.predict_proba(data_predict_autoencoder_test_data)[:,1]
test_pred_bin = RF_T.predict(data_predict_autoencoder_test_data)

fpr, tpr, _ = roc_curve(y_test, test_pred)
auc = roc_auc_score(y_test, test_pred)
accuracy = accuracy_score(y_test, test_pred_bin)
f1 = f1_score(y_test, test_pred_bin)
precision =  precision_score(y_test, test_pred_bin)
recall = recall_score(y_test, test_pred_bin)

print('FP, TP              :', "%0.2f" % sum(fpr), "%0.2f" % sum(tpr))
print('ROC_AUC_SCORE       :', "%0.2f" % auc)
print('accuracy            :', "%0.2f" % accuracy)
print('precision           :', "%0.2f" % precision)
print('recall              :', "%0.2f" % recall)
print('f1                  :', "%0.2f" % f1)

print('val, train  AUC     :', "%0.2f" % roc_auc_score(y_test, test_pred), "%0.2f" % roc_auc_score(y_train, RF_T.predict_proba(data_predict_autoencoder_X)[:,1]))
print('val, train  AUC_2   :', "%0.2f" % roc_auc_score(y_test, test_pred_bin), "%0.2f" % roc_auc_score(y_train, RF_T.predict(data_predict_autoencoder_X)))

print(confusion_matrix(y_test, test_pred_bin))
print(classification_report(y_test, RF_T.predict(data_predict_autoencoder_test_data)))
# Out:
# FP, TP              : 34.04 111.97
# ROC_AUC_SCORE       : 0.90
# accuracy            : 0.77
# precision           : 0.91
# recall              : 0.41
# f1                  : 0.56
# val, train  AUC     : 0.90 1.00
# val, train  AUC_2   : 0.69 1.00
# [[2441   56]
#  [ 827  567]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85      2497
#            1       0.91      0.41      0.56      1394
#
#     accuracy                           0.77      3891
#    macro avg       0.83      0.69      0.70      3891
# weighted avg       0.81      0.77      0.74      3891

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13, shuffle = False)
scale_pos_weight = sum(y_train == 0) / (1.0 * sum(y_train == 1))

RF_T = LogisticRegression(random_state=0, n_jobs=-1)
RF_T.fit(data_predict_autoencoder_X, y_train)

test_pred = RF_T.predict_proba(data_predict_autoencoder_test_data)[:,1]
test_pred_bin = RF_T.predict(data_predict_autoencoder_test_data)

fpr, tpr, _ = roc_curve(y_test, test_pred)
auc = roc_auc_score(y_test, test_pred)
accuracy = accuracy_score(y_test, test_pred_bin)
f1 = f1_score(y_test, test_pred_bin)
precision =  precision_score(y_test, test_pred_bin)
recall = recall_score(y_test, test_pred_bin)

print('FP, TP              :', "%0.2f" % sum(fpr), "%0.2f" % sum(tpr))
print('ROC_AUC_SCORE       :', "%0.2f" % auc)
print('accuracy            :', "%0.2f" % accuracy)
print('precision           :', "%0.2f" % precision)
print('recall              :', "%0.2f" % recall)
print('f1                  :', "%0.2f" % f1)

print('val, train  AUC     :', "%0.2f" % roc_auc_score(y_test, test_pred), "%0.2f" % roc_auc_score(y_train, RF_T.predict_proba(data_predict_autoencoder_X)[:,1]))
print('val, train  AUC_2   :', "%0.2f" % roc_auc_score(y_test, test_pred_bin), "%0.2f" % roc_auc_score(y_train, RF_T.predict(data_predict_autoencoder_X)))

print(confusion_matrix(y_test, test_pred_bin))
print(classification_report(y_test, RF_T.predict(data_predict_autoencoder_test_data)))
# Out:
# FP, TP              : 194.84 668.72
# ROC_AUC_SCORE       : 0.90
# accuracy            : 0.80
# precision           : 0.85
# recall              : 0.54
# f1                  : 0.66
# val, train  AUC     : 0.90 0.94
# val, train  AUC_2   : 0.74 0.87
# [[2362  135]
#  [ 643  751]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86      2497
#            1       0.85      0.54      0.66      1394
#
#     accuracy                           0.80      3891
#    macro avg       0.82      0.74      0.76      3891
# weighted avg       0.81      0.80      0.79      3891

# %%
RF_T = lgb.LGBMClassifier(num_leaves=20, learning_rate=0.04, n_estimators=int(1000*1),
                                          colsample_bytree=0.5, subsample=0.5,
                                          n_jobs=-1, random_state=0)
RF_T.fit(data_predict_autoencoder_X, y_train)

test_pred = RF_T.predict_proba(data_predict_autoencoder_test_data)[:,1]
test_pred_bin = RF_T.predict(data_predict_autoencoder_test_data)

fpr, tpr, _ = roc_curve(y_test, test_pred)
auc = roc_auc_score(y_test, test_pred)
accuracy = accuracy_score(y_test, test_pred_bin)
f1 = f1_score(y_test, test_pred_bin)
precision =  precision_score(y_test, test_pred_bin)
recall = recall_score(y_test, test_pred_bin)

print('FP, TP              :', "%0.2f" % sum(fpr), "%0.2f" % sum(tpr))
print('ROC_AUC_SCORE       :', "%0.2f" % auc)
print('accuracy            :', "%0.2f" % accuracy)
print('precision           :', "%0.2f" % precision)
print('recall              :', "%0.2f" % recall)
print('f1                  :', "%0.2f" % f1)

print('val, train  AUC     :', "%0.2f" % roc_auc_score(y_test, test_pred), "%0.2f" % roc_auc_score(y_train, RF_T.predict_proba(data_predict_autoencoder_X)[:,1]))
print('val, train  AUC_2   :', "%0.2f" % roc_auc_score(y_test, test_pred_bin), "%0.2f" % roc_auc_score(y_train, RF_T.predict(data_predict_autoencoder_X)))

print(confusion_matrix(y_test, test_pred_bin))
print(classification_report(y_test, RF_T.predict(data_predict_autoencoder_test_data)))
# Out:
# FP, TP              : 222.45 736.99
# ROC_AUC_SCORE       : 0.90
# accuracy            : 0.81
# precision           : 0.91
# recall              : 0.52
# f1                  : 0.66
# val, train  AUC     : 0.90 1.00
# val, train  AUC_2   : 0.74 1.00
# [[2428   69]
#  [ 674  720]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.87      2497
#            1       0.91      0.52      0.66      1394
#
#     accuracy                           0.81      3891
#    macro avg       0.85      0.74      0.76      3891
# weighted avg       0.83      0.81      0.79      3891

# %%
data_test_fin = scaler.transform(test_data)

# %%
predict_autoencoder_fin = autoencoder.predict(data_test_fin)

# %%
data_predict_autoencoder_fin = pd.DataFrame(predict_autoencoder_fin.reshape(predict_autoencoder_fin.shape[0], predict_autoencoder_fin.shape[1]))

# %%
test['TARGET'] = RF_T.predict_proba(data_predict_autoencoder_fin)[:,1]
test[['id_contract', 'TARGET']].to_csv('fin_1.csv', sep=';', index=False)
test[['id_contract', 'TARGET']].head()
# Out:
#    id_contract    TARGET
# 0        17892  0.107750
# 1        17893  0.006122
# 2        17894  0.035927
# 3        17895  0.207422
# 4        17896  0.054934
